# %% [markdown]
# # **INDEXING PIPELINE**
# Indexing: a pipeline for ingesting data from a source and indexing it. This usually happens offline.

# %% [markdown]
# ### **Importing the Libraries**

# %%
# Loader
from langchain.document_loaders import CSVLoader
# for embedding model
from langchain_community.embeddings.fastembed import FastEmbedEmbeddings
# for vector database
from langchain.vectorstores import FAISS

# %% [markdown]
# ## **Data Ingestion**

# %% [markdown]
# **Loading Data from CSV using CSVLoader**

# %%
loader = CSVLoader(
    file_path='D:\PROJECTS\Gen Ai Projects\KS RAG Application\data\processed\combined_data.csv',
    source_column = 'question',
    encoding="Windows-1252",
)
data = loader.load()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Maaz PC\AppData\Local\Temp\ipykernel_9368\2897254002.py:2: SyntaxWarning: invalid escape sequence '\P'
#   file_path='D:\PROJECTS\Gen Ai Projects\KS RAG Application\data\processed\combined_data.csv',

# %% [markdown]
# ### **Initializing Embedding Model**

# %%
fast_embeddings = FastEmbedEmbeddings()
# Out:
# Fetching 5 files: 100%|██████████| 5/5 [00:00<?, ?it/s]

# %% [markdown]
# ### **Creating Vector Database**

# %%
vector_db = FAISS.from_documents(documents= data, embedding= fast_embeddings)

# %% [markdown]
# ### **Storing Vector Database**

# %%
vector_db.save_local('D:/PROJECTS/Gen Ai Projects/KS RAG Application/vector_db/faiss.index')
